# %% [markdown]
# # Main function for the visualization

# %%
# %run utils.ipynb # Run the utils notebook

# %%
image_path = './images/2.jpg'
meta_data_json_path = './data/2.json'
opacity = 0.8

# %%
tp1, tp2 = draw_image(image_path,
                     meta_data_json_path,
                     opacity)

# %%
tp1
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=640x480 at 0x1227C90D0>

# %%
tp2
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=640x480 at 0x1227870A0>
